# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaswanth-Reddy-S/MT/blob/master/text_generation_gpt2-simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Tue Apr  6 05:57:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 338Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.15Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 527Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:14, 34.0Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 393Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.65Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 4.06Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = "/content/text generator.txt"

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=1000,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.87s/it]
# dataset has 338024 tokens
# Training...
# [10 | 28.48] loss=3.68 avg=3.68
# [20 | 49.97] loss=3.47 avg=3.57
# [30 | 71.80] loss=3.40 avg=3.51
# [40 | 94.00] loss=3.22 avg=3.44
# [50 | 116.61] loss=3.63 avg=3.48
# [60 | 139.67] loss=3.22 avg=3.43
# [70 | 163.02] loss=3.05 avg=3.38
# [80 | 185.93] loss=3.21 avg=3.36
# [90 | 208.90] loss=3.25 avg=3.34
# [100 | 232.12] loss=3.09 avg=3.32
# [110 | 255.19] loss=3.02 avg=3.29
# [120 | 278.21] loss=3.45 avg=3.30
# ...

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run1')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-1000

# %%
gpt2.generate(sess, run_name='run1')
# Out:
# BALTHASAR:
# Good my lord, do not despair;
# I'll serve you as you would do sworn,
# Not against your time, but toward your coming:
# Ten days since I heard the king speak,
# And then I was circumambulate.
#
# CATESBY:
# What, no appointment?
#
# BALTHASAR:
# No, most obedient, sir.
#
# CATESBY:
# We do owe allegiance unto the king;
# And here is the matter of our authority.
#
# BALTHASAR:
# Sir, I perceive
# The nobility of your cause are not pleased
# With what you say you are.
#
# GREY:
# Ay, and the king, too.
#
# CATESBY:
# They are most affable men, sir, I think,
# Whose common friends are offended too rashly.
#
# BALTHASAR:
# I doubt not, sir, that you are most free,
# Without descending into their vehement faults:
# I know, and will abide it, in great mine own.
#
# ESCALUS:
# Are they not cowards, I rod myself, that
# I can shake off the influence of their calumny?
#
# BALTHASAR:
# Ay, sir, they are not i' the wrong I, they are calumny.
#
# ESCALUS:
# ...

# %%
gpt2.generate(sess,
              length=250,
              temperature=0.7,
              prefix="LORD",
              nsamples=5,
              batch_size=5
              )
# Out:
# LORD FITZWATER:
# No more of this; it shall make me blench for revenge.
#
# BUSHY:
# Sir, I hope your business give occasion.
#
# QUEEN:
# No, if they do not, then I see my state
# Drawn And Used, And Still Of MARCIUS CORIOLANUS:
# GREECE:
# How many of you do, cousins?
#
# CURTIS:
#  Few, I fear, but that do follow.
#
# QUEEN:
# How many of you do follow me?
#
# CORIOLANUS:
#  Few, I fear, but that do follow.
#
# CORIOLANUS:
# Well, gentlemen, we must our business.
#
# MENENIUS:
# I'll follow you.
#
# COMINIUS:
# We follow her: if she inform us your custom.
#
# CORIOLANUS:
# Not I: I would that you did.
#
# CORIOLANUS:
# I would neither.
#
# MENENIUS:
# Your voices?
#
# CORIOLANUS:
# True, I love them not: but to
# ...
# LORD FITZWATER:
# Good my lords, give me leave to retire:
# I am the midwife to a son of York,
#  Marquis OF YORK, Marquis OF YORK.
#
# HENRY PERCY:
# My lord, the king is come to open the gate,
# And bid Lancaster open the gate:
# If upon my person that is person,
# ...

# %%
gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=500,
                      temperature=0.7,
                      nsamples=100,
                      batch_size=20
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %%
model_name = "774M"

gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 541Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.76Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 260Mit/s]
# Fetching model.ckpt.data-00000-of-00001:   1%|▏               | 34.6M/3.10G [00:07<11:08, 4.58Mit/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a51a2e8cdf91> in <module>()
#       1 model_name = "774M"
#       2
# ----> 3 gpt2.download_gpt2(model_name=model_name)
#
# /usr/local/lib/python3.7/dist-packages/gpt_2_simple/gpt_2.py in download_gpt2(model_dir, model_name)
#      91                                     sub_dir=sub_dir,
#      92                                     model_name=model_name,
# ---> 93                                     file_name=file_name)
#      94
#      95
#
# ...

# %%
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, model_name=model_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e8a3f5c6cb77> in <module>()
#       1 sess = gpt2.start_tf_sess()
#       2
# ----> 3 gpt2.load_gpt2(sess, model_name=model_name)
#
# /usr/local/lib/python3.7/dist-packages/gpt_2_simple/gpt_2.py in load_gpt2(sess, checkpoint, run_name, checkpoint_dir, model_name, model_dir, multi_gpu)
#     388         gpus = get_available_gpus()
#     389
# --> 390     output = model.model(hparams=hparams, X=context, gpus=gpus)
#     391
#     392     if checkpoint=='latest':
#
# /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/model.py in model(hparams, X, past, scope, gpus, reuse)
#     181
#     182         wpe = tf.compat.v1.get_variable('wpe', [hparams.n_ctx, hparams.n_embd],
# --> 183                              initializer=tf.compat.v1.random_normal_initializer(stddev=0.01))
# ...

# %%
gpt2.generate(sess,
              model_name=model_name,
              prefix="The secret of life is",
              length=100,
              temperature=0.7,
              top_p=0.9,
              nsamples=5,
              batch_size=5
              )
